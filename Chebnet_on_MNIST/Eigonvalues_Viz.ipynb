# %% [markdown]
# # Look at eigonvalues / spectrum of different Laplacians

# %%
import os
import sys
#import time
import numpy as np

# -------------Torch-------------------
import torch
from torch.utils.data import DataLoader

# -------------Graph-------------------
import dgl
import networkx as nx
import matplotlib.pyplot as plt

from utils import set_device
from laplacian import normalized_laplacian

sys.path.insert(0, "lib/")
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from graphs import regular_2D_lattice

g = regular_2D_lattice(15)
pos=nx.spectral_layout(g.to_networkx().to_undirected())
nx.draw(g.to_networkx().to_undirected(),pos)
# Out:
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
import numpy.linalg
def eigonvals(g):
    L = nx.normalized_laplacian_matrix(g)
    e = numpy.linalg.eigvals(L.A)
    print("Largest eigenvalue:", max(e))
    print("Smallest eigenvalue:", min(e))
    plt.hist(e, bins=150)  # histogram with 100 bins
    plt.xlim(-0.2, 2.2)  # eigenvalues between 0 and 2
    plt.show()

# %%
eigonvals(g.to_networkx().to_undirected())
# Out:
# Largest eigenvalue: (2.000000000000004+0j)
# Smallest eigenvalue: (-5.178127370709016e-16+0j)
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/numpy/lib/histograms.py:844: ComplexWarning: Casting complex values to real discards the imaginary part
#   indices = f_indices.astype(np.intp)
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
G = g.to_networkx().to_undirected()
L = nx.normalized_laplacian_matrix(G)
e = numpy.linalg.eigvals(L.A)
print("Largest eigenvalue:", max(e))
print("Smallest eigenvalue:", min(e))
plt.plot(np.sort(e),'.')  # histogram with 100 bins
#plt.xlim(-0.2, 2.2)  # eigenvalues between 0 and 2
plt.show()
# Out:
# Largest eigenvalue: (2.000000000000004+0j)
# Smallest eigenvalue: (-5.178127370709016e-16+0j)
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
from graphs import regular_2D_lattice_8_neighbors

g2 = regular_2D_lattice_8_neighbors(15)
nx.draw(g2.to_networkx().to_undirected(),pos,node_color=np.array(g2.to_networkx().to_undirected().degree())[:,1],cmap=plt.cm.viridis)
# Out:
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
G2 = g2.to_networkx().to_undirected()
L2 = nx.normalized_laplacian_matrix(G2)
e2 = numpy.linalg.eigvals(L2.A)
print("Largest eigenvalue:", max(e2))
print("Smallest eigenvalue:", min(e2))
# Out:
# Largest eigenvalue: 1.516975589628199
# Smallest eigenvalue: 3.469446951953614e-17

# %%
plt.plot(np.sort(e))  # histogram with 100 bins
plt.plot(np.sort(e2))
plt.show()
# Out:
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.hist(e2, bins=100)  # histogram with 100 bins
plt.hist(e, bins=100)  # histogram with 100 bins
plt.xlim(-0, 2)  # eigenvalues between 0 and 2
plt.show()
# Out:
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/numpy/lib/histograms.py:844: ComplexWarning: Casting complex values to real discards the imaginary part
#   indices = f_indices.astype(np.intp)
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %%
from graphs import random_edge_suppression

g3 = random_edge_suppression(15, 150)
nx.draw(g3.to_networkx().to_undirected(), pos, node_color=np.array(
g3.to_networkx().to_undirected().degree())[:, 1], cmap=plt.cm.viridis)
pass
# Out:
# /Users/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
#
#
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.

# %%
G3 = g3.to_networkx().to_undirected()
L3 = nx.normalized_laplacian_matrix(G3)
e3 = numpy.linalg.eigvals(L3.A)
print("Largest eigenvalue:", max(e3))
print("Smallest eigenvalue:", min(e3))
plt.plot(np.sort(e3),'.')  # histogram with 100 bins
#plt.xlim(-0.2, 2.2)  # eigenvalues between 0 and 2
plt.show()
# Out:
# Largest eigenvalue: 2.0000000000000115
# Smallest eigenvalue: -1.0905010751997164e-16

# %%
print("Largest eigenvalue:", max(e3))
print("Smallest eigenvalue:", min(e3))
plt.hist(e3, bins=100)  # histogram with 100 bins
plt.xlim(-0.1, 2.1)  # eigenvalues between 0 and 2
plt.show()
# Out:
# Largest eigenvalue: 2.0000000000000115
# Smallest eigenvalue: -1.0905010751997164e-16

# %%
plt.plot(np.sort(e))  # histogram with 100 bins
plt.plot(np.sort(e2))
plt.plot(np.sort(e3))
plt.show()
