# %% [markdown]
# # Superpixel learning

# %%
import matplotlib.pyplot as plt
import dgl
from torch.utils.data import DataLoader
import torch
import time
import os
import sys
sys.path.insert(0, "../lib/")
import laplacian
import ninja
import sys
import utils
import model
import graphs
from utils import set_device
from laplacian import normalized_laplacian


# Autoreload
# %load_ext autoreload
# %autoreload 2

# GPU
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

device = set_device(verbose=True)
# Out:
# cuda available

# %% [markdown]
# # MNIST Superpixel

# %%
from superpixels import SuperPixDataset
DATASET_NAME = 'MNIST'
dataset = SuperPixDataset(DATASET_NAME)  # 54s
trainset, valset, testset = dataset.train, dataset.val, dataset.test
# Out:
# [I] Loading dataset MNIST...
# <_io.BufferedReader name='../Datasets/superpixels/MNIST.pkl'>
# train, test, val sizes : 55000 10000 5000
# [I] Finished loading.
# [I] Data load time: 37.7043s

# %% [markdown]
# ## Visualise the dataset

# %%
import networkx as nx
import random
from ninja import GeigplotL
plt.figure(figsize=(15,7))

plt.subplot(121)
g_demo, l_demo = trainset[random.randrange(45000)]
nx.draw(g_demo.to_networkx().to_undirected(),
        node_color=g_demo.ndata['feat'][:,0],
        pos = g_demo.ndata['feat'][:,1:3].numpy(),
        node_size=800,
        cmap='copper' )

print('Label:',l_demo)
print('graph:',g_demo)

plt.subplot(122)
GeigplotL(g_demo)
plt.show()
# Out:
# Label: tensor(8)
# graph: DGLGraph(num_nodes=73, num_edges=584,
#          ndata_schemes={'feat': Scheme(shape=(3,), dtype=torch.float16)}
#          edata_schemes={'feat': Scheme(shape=(1,), dtype=torch.float16)})
# Largest eigenvalue: 1.392201185783011
# Smallest eigenvalue: 1.1102230246251565e-16

# %%
from utils import chebyshev
from laplacian import normalized_laplacian
L = normalized_laplacian(g_demo).to_dense()
Fmap = chebyshev(L,g_demo.ndata['feat'][:,0:3].float() ,3)

nx.draw(g_demo.to_networkx().to_undirected(),
        node_color=Fmap[1][:,0],
        node_size=800,
        pos = g_demo.ndata['feat'][:,1:3].numpy(),
        cmap='viridis')
# Out:
# /home/axel/miniconda3/envs/DGL/lib/python3.7/site-packages/dgl/base.py:25: UserWarning: Currently adjacency_matrix() returns a matrix with destination as rows by default.  In 0.5 the result will have source as rows (i.e. transpose=True)
#   warnings.warn(msg, warn_type)

# %% [raw]
# CIFAR: '0' airplane, '1' automobile, '2' bird, '3' cat, '4' deer, '5' dog, '6' frog, '7' horse, '8' ship, '9' truck

# %% [markdown]
# # Model definition for training

# %%
from model import DGL_mean_Classifier_modded
# model_parameters
in_features = 3
first_conv_out = 64
second_conv_out = 128
hidden_layer_classifier = 128
k = 4
n_classes = 10

net = DGL_mean_Classifier_modded(
    in_features, 
    first_conv_out, 
    second_conv_out, 
    hidden_layer_classifier, 
    n_classes, 
    k,
    readout="max"
)

print(net)
if torch.cuda.is_available():
    net.to(device)
# Out:
# DGL_mean_Classifier_modded(
#   (layers): ModuleList(
#     (0): Cheb_Conv(
#       (fc): Linear(in_features=12, out_features=64, bias=True)
#     )
#     (1): Cheb_Conv(
#       (fc): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (2): Cheb_Conv(
#       (fc): Linear(in_features=512, out_features=256, bias=True)
#     )
#     (3): Cheb_Conv(
#       (fc): Linear(in_features=1024, out_features=512, bias=True)
#     )
#   )
#   (MLP): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
from utils import load_model
#net.load_state_dict(load_model('Cheb_superpix_overfit'))

# %% [markdown]
# # Training pipe

# %%
import torch.optim as optim
import torch.nn as nn
#
from utils import collate, collate2
#

train_loader = DataLoader(trainset, batch_size=128,
                         shuffle=True, collate_fn=collate2, drop_last=True, pin_memory=False)
val_loader =  DataLoader(valset, batch_size=500,
                         shuffle=False, collate_fn=collate2, drop_last=True, pin_memory=False)
test_loader =  DataLoader(testset, batch_size=500,
                         shuffle=False, collate_fn=collate2, drop_last=True, pin_memory=True)

loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.99)

epoch_losses = []

# %% [markdown]
# , (torch.ones(2048)*1.4).to(device)

# %%
def train(model, device, data_loader, epochs, loss_func, optimizer, scheduler):

    for epoch in range(epochs):
        model.train()
        epoch_loss = 0
        correct = 0
        t0 = time.time()

        for iter, (bGraph, label) in enumerate(data_loader):
            bGraph, label = bGraph.to(device), label.to(device)
            
            #lmax = normalized_laplacian(bGraph)
            #print(lmax)
            output = model(bGraph, 
                           bGraph.ndata.pop('feat').float().to(device),
                           (torch.ones(2048)*1.4).to(device) )
            loss = loss_func(output, label.to(device))

            # sum up batch loss
            epoch_loss += loss.detach().item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # get the index of the max log-probability
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(label.view_as(pred)).sum().item()

        epoch_loss /= iter + 1
        
        val_loss = test(net, device, val_loader, False)

        scheduler.step()

        print(
            "Epoch {} loss - train {:.4f} - val {:.4f} - Acc: {} ({:.1f}%) in {:.1f}s".format(
                epoch, epoch_loss, val_loss, correct,
            100 * correct / len(data_loader.dataset), time.time() - t0
            )
        )
        epoch_losses.append([epoch_loss, val_loss])

# %%
def test(model, device, data_loader, verbose=True):
    model.eval()
    test_loss = 0
    correct = 0
    tot_label = []
    tot_pred = []

    with torch.no_grad():
        for iter, (Bgraph, label) in enumerate(data_loader):
            Bgraph, label = Bgraph.to(device), label.to(device)

            output = model(Bgraph, Bgraph.ndata['feat'].float(), (torch.ones(1000)*1.4).to(device))
            # sum up batch loss
            test_loss += loss_func(output, label.to(device)).item()

            # get the index of the max log-probability
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(label.view_as(pred)).sum().item()

            tot_label.append(label.cpu())
            tot_pred.append(pred.cpu())

    # for the classification report
    tot_label = torch.stack(tot_label).view(-1).cpu()
    tot_pred = torch.stack(tot_pred).view(-1).cpu()

    test_loss /= iter + 1

    if verbose:
        print('\n Average loss per epoch: {:.4f},Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

        # BATCHED DGL EXAMPLE
        import sklearn
        from sklearn.metrics import classification_report

        print(sklearn.metrics.classification_report(tot_label, tot_pred))

    else:
        return test_loss

# %% [markdown]
# ## Training time

# %%
train(net, device, train_loader, 40, loss_func,optimizer, scheduler)
# Out:
# Epoch 0 loss - train 1.4493 - val 0.7100 - Acc: 26281 (47.8%) in 23.6s
# Epoch 1 loss - train 0.5456 - val 0.3674 - Acc: 45039 (81.9%) in 22.5s
# Epoch 2 loss - train 0.3468 - val 0.2971 - Acc: 48757 (88.6%) in 22.7s
# Epoch 3 loss - train 0.2647 - val 0.2430 - Acc: 50267 (91.4%) in 22.5s
# Epoch 4 loss - train 0.2191 - val 0.1960 - Acc: 51017 (92.8%) in 25.6s
# Epoch 5 loss - train 0.1829 - val 0.1766 - Acc: 51693 (94.0%) in 26.7s
# Epoch 6 loss - train 0.1634 - val 0.1908 - Acc: 51982 (94.5%) in 26.9s
# Epoch 7 loss - train 0.1353 - val 0.1671 - Acc: 52498 (95.5%) in 27.3s
# Epoch 8 loss - train 0.1207 - val 0.1577 - Acc: 52752 (95.9%) in 27.8s
# Epoch 9 loss - train 0.1023 - val 0.1876 - Acc: 53085 (96.5%) in 28.2s
# Epoch 10 loss - train 0.0882 - val 0.1810 - Acc: 53307 (96.9%) in 28.4s
# Epoch 11 loss - train 0.0735 - val 0.1907 - Acc: 53555 (97.4%) in 28.1s
# Epoch 12 loss - train 0.0653 - val 0.1856 - Acc: 53691 (97.6%) in 28.4s
# Epoch 13 loss - train 0.0571 - val 0.2152 - Acc: 53826 (97.9%) in 28.7s
# Epoch 14 loss - train 0.0506 - val 0.2033 - Acc: 53933 (98.1%) in 29.0s
# Epoch 15 loss - train 0.0375 - val 0.2001 - Acc: 54218 (98.6%) in 28.6s
# Epoch 16 loss - train 0.0359 - val 0.1963 - Acc: 54202 (98.5%) in 28.5s
# Epoch 17 loss - train 0.0334 - val 0.2207 - Acc: 54244 (98.6%) in 27.8s
# Epoch 18 loss - train 0.0414 - val 0.2086 - Acc: 54117 (98.4%) in 27.1s
# Epoch 19 loss - train 0.0246 - val 0.2366 - Acc: 54445 (99.0%) in 27.5s
# Epoch 20 loss - train 0.0264 - val 0.2485 - Acc: 54416 (98.9%) in 27.6s
# Epoch 21 loss - train 0.0260 - val 0.2225 - Acc: 54428 (99.0%) in 27.8s
# Epoch 22 loss - train 0.0247 - val 0.3224 - Acc: 54444 (99.0%) in 28.7s
# Epoch 23 loss - train 0.0197 - val 0.2287 - Acc: 54542 (99.2%) in 28.6s
# Epoch 24 loss - train 0.0222 - val 0.2883 - Acc: 54488 (99.1%) in 28.5s
# Epoch 25 loss - train 0.0173 - val 0.2565 - Acc: 54585 (99.2%) in 28.8s
# Epoch 26 loss - train 0.0189 - val 0.2702 - Acc: 54561 (99.2%) in 28.8s
# Epoch 27 loss - train 0.0222 - val 0.2335 - Acc: 54481 (99.1%) in 28.5s
# Epoch 28 loss - train 0.0152 - val 0.3007 - Acc: 54630 (99.3%) in 28.2s
# Epoch 29 loss - train 0.0206 - val 0.3425 - Acc: 54505 (99.1%) in 28.8s
# Epoch 30 loss - train 0.0180 - val 0.3057 - Acc: 54559 (99.2%) in 29.0s
# Epoch 31 loss - train 0.0182 - val 0.2788 - Acc: 54564 (99.2%) in 29.3s
# Epoch 32 loss - train 0.0101 - val 0.2828 - Acc: 54720 (99.5%) in 29.0s
# Epoch 33 loss - train 0.0168 - val 0.2900 - Acc: 54565 (99.2%) in 28.4s
# Epoch 34 loss - train 0.0121 - val 0.2986 - Acc: 54699 (99.5%) in 27.7s
# Epoch 35 loss - train 0.0161 - val 0.2737 - Acc: 54619 (99.3%) in 27.9s
# Epoch 36 loss - train 0.0146 - val 0.2903 - Acc: 54643 (99.4%) in 27.7s
# Epoch 37 loss - train 0.0155 - val 0.2723 - Acc: 54615 (99.3%) in 28.4s
# Epoch 38 loss - train 0.0106 - val 0.3110 - Acc: 54715 (99.5%) in 28.1s
# Epoch 39 loss - train 0.0172 - val 0.3063 - Acc: 54599 (99.3%) in 29.1s

# %%
plt.title("cross entropy averaged over minibatches, over epochs")
plt.plot(epoch_losses)
plt.legend(['train','val'])
plt.show()

# %%
torch.cuda.empty_cache()

# %% [markdown]
# ## Test Metrics

# %%
test(net,device,test_loader)
torch.cuda.empty_cache()
# Out:
#  Average loss per epoch: 0.3204,Accuracy: 9488/10000 (95%)
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       980
#            1       0.95      1.00      0.97      1135
#            2       0.95      0.96      0.96      1032
#            3       0.94      0.95      0.94      1010
#            4       0.97      0.91      0.94       982
#            5       0.93      0.94      0.93       892
#            6       0.97      0.96      0.96       958
#            7       0.94      0.95      0.94      1028
#            8       0.94      0.93      0.93       974
#            9       0.93      0.91      0.92      1009
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000

# %% [markdown]
# ## Saving

# %%
from utils import save_model

#save_model("Cheb_superpix_overfit_mean", net)
